# %%
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import scipy

# %%
# extracting features from this bearing data

feature_matrix=np.zeros((1,10))
feature_matrix

def compute_skewness(x):
    
    n = len(x)
    third_moment = np.sum((x - np.mean(x))**3) / n
    s_3 = np.std(x, ddof = 1) ** 3
    return third_moment/s_3

def compute_kurtosis(x):
    
    n = len(x)
    fourth_moment = np.sum((x - np.mean(x))**4) / n
    s_4 = np.std(x, ddof = 1) ** 4
    return fourth_moment / s_4 - 3

# %%
Time_feature_matrix_8=pd.DataFrame()
path=r'C:\Users\User\Desktop\originalrollerA-2/'
for filename in os.listdir(path):
    
    dt=pd.read_csv(os.path.join(path, filename),header=None, lineterminator='\n')
    dt=dt.drop(labels=0, axis=0)
    dt = dt.apply( pd.to_numeric, errors='coerce' )
    
    bearing_data = np.array(dt[0])

    feature_matrix=np.zeros((1,10))
    temp = bearing_data
    feature_matrix[0,0] = np.max(temp)
    feature_matrix[0,1] = np.min(temp)
    feature_matrix[0,2] = np.mean(temp)
    feature_matrix[0,3] = np.std(temp, ddof = 1)
    feature_matrix[0,4] = np.sqrt(np.mean(temp ** 2))
    feature_matrix[0,5] = compute_skewness(temp)
    feature_matrix[0,6] = compute_kurtosis(temp)
    feature_matrix[0,7] = feature_matrix[0,0]+feature_matrix [0,1]
    feature_matrix[0,8] = feature_matrix[0,0]/feature_matrix[0,4]
    feature_matrix[0,9] = feature_matrix[0,3] ** 2
    
    df = pd.DataFrame(feature_matrix)
    df.index=[filename[:-3]]
    df.columns = ['Max','Min','Mean','Std','RMS','Skewness','Kurtosis','P2P','Crest Factor','Variance']
    
    Time_feature_matrix_8 = Time_feature_matrix_8.append(df)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17356\1500127949.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Time_feature_matrix_8 = Time_feature_matrix_8.append(df)
# C:\Users\User\AppData\Local\Temp\ipykernel_17356\1500127949.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Time_feature_matrix_8 = Time_feature_matrix_8.append(df)
# C:\Users\User\AppData\Local\Temp\ipykernel_17356\1500127949.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Time_feature_matrix_8 = Time_feature_matrix_8.append(df)
# C:\Users\User\AppData\Local\Temp\ipykernel_17356\1500127949.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
Time_feature_matrix_8
# Out:
#                         Max   Min      Mean       Std       RMS  Skewness  \
# ROLLER FAULT25.xlsx1.  0.36 -0.19  0.156204  0.041061  0.161506 -0.807182
# ROLLER FAULT26.xlsx1.  0.51 -0.20  0.153582  0.078895  0.172643  0.232209
# ROLLER FAULT27.xlsx1.  1.13 -0.10  0.150838  0.084108  0.172682  1.612978
# ROLLER FAULT28.xlsx1.  1.00 -0.10  0.149424  0.085048  0.171911  1.442888
# ROLLER FAULT30.xlsx1.  1.02 -0.10  0.146847  0.079799  0.167110  1.504353
# ...                     ...   ...       ...       ...       ...       ...
# ROLLER FAULT85.xlsx1.  0.65 -0.20  0.137798  0.101228  0.170953  0.565342
# ROLLER FAULT86.xlsx1.  1.20 -0.40  0.142249  0.112648  0.181416  1.490079
# ROLLER FAULT87.xlsx1.  0.63 -0.20  0.137271  0.105348  0.173004  0.849797
# ROLLER FAULT88.xlsx1.  0.73 -0.20  0.141852  0.104046  0.175888  0.572960
# ROLLER FAULT90.xlsx1.  0.68 -0.50  0.140363  0.106718  0.176292  0.274460
#
#                         Kurtosis   P2P  Crest Factor  Variance
# ...

# %%
df3=Time_feature_matrix_8

# %%
df3
# Out:
#                         Max   Min      Mean       Std       RMS  Skewness  \
# ROLLER FAULT25.xlsx1.  0.36 -0.19  0.156204  0.041061  0.161506 -0.807182
# ROLLER FAULT26.xlsx1.  0.51 -0.20  0.153582  0.078895  0.172643  0.232209
# ROLLER FAULT27.xlsx1.  1.13 -0.10  0.150838  0.084108  0.172682  1.612978
# ROLLER FAULT28.xlsx1.  1.00 -0.10  0.149424  0.085048  0.171911  1.442888
# ROLLER FAULT30.xlsx1.  1.02 -0.10  0.146847  0.079799  0.167110  1.504353
# ...                     ...   ...       ...       ...       ...       ...
# ROLLER FAULT85.xlsx1.  0.65 -0.20  0.137798  0.101228  0.170953  0.565342
# ROLLER FAULT86.xlsx1.  1.20 -0.40  0.142249  0.112648  0.181416  1.490079
# ROLLER FAULT87.xlsx1.  0.63 -0.20  0.137271  0.105348  0.173004  0.849797
# ROLLER FAULT88.xlsx1.  0.73 -0.20  0.141852  0.104046  0.175888  0.572960
# ROLLER FAULT90.xlsx1.  0.68 -0.50  0.140363  0.106718  0.176292  0.274460
#
#                         Kurtosis   P2P  Crest Factor  Variance
# ...

# %%
path=r'C:\Users\User\Desktop\ '
df3.to_csv(path+'health.csv')

# %%
df_inner=df3
fault=[]
defect=[]
for i in range (0,len(df_inner)):
    fault.append('inner')
    defect.append('Yes')
    
df_inner['Fault']=fault
df_inner['Defect']=defect
df_inner.to_csv('innerA3.csv',index=True)

# %%
df3
# Out:
#                           Max  Min      Mean       Std       RMS   Skewness  \
# Inner (A-3)  1.xlsx1.    0.90 -1.0 -0.025664  0.116444  0.119181  -0.297772
# Inner (A-3)  10.xlsx1.   0.81 -0.9 -0.025271  0.110987  0.113774  -0.650691
# Inner (A-3)  100.xlsx1.  0.27 -0.8 -0.031998  0.099887  0.104839  -0.760919
# Inner (A-3)  101.xlsx1.  0.96 -0.4 -0.025612  0.099701  0.102889   0.606337
# Inner (A-3)  11.xlsx1.   0.29 -1.0 -0.022477  0.109053  0.111292  -1.033958
# ...                       ...  ...       ...       ...       ...        ...
# Inner (A-3)  94.xlsx1.   0.26 -8.0 -0.049858  0.327518  0.331127 -18.069714
# Inner (A-3)  95.xlsx1.   0.38 -0.9 -0.026855  0.103655  0.107027  -0.752649
# Inner (A-3)  96.xlsx1.   0.27 -0.4 -0.020945  0.097506  0.099682  -0.342596
# Inner (A-3)  98.xlsx1.   0.75 -1.0 -0.025267  0.111543  0.114314  -1.606908
# Inner (A-3)  99.xlsx1.   0.88 -0.5 -0.030956  0.105145  0.109556   0.371611
#
# ...

# %%
in1=pd.read_csv(r'C:\Users\User\Desktop\innerdataset\innerA1.csv')
in2=pd.read_csv(r'C:\Users\User\Desktop\innerdataset\innerA2.csv')
in3=pd.read_csv(r'C:\Users\User\Desktop\innerdataset\innerA3.csv')

# %%
in1
# Out:
#                  Unnamed: 0   Max  Min      Mean       Std       RMS  \
# 0   Inner (A-1)  100.xlsx1.  0.32 -0.2  0.047824  0.064290  0.080101
# 1   Inner (A-1)  101.xlsx1.  0.96 -0.2  0.049203  0.074959  0.089633
# 2   Inner (A-1)  102.xlsx1.  0.90 -0.2  0.047670  0.067443  0.082561
# 3   Inner (A-1)  103.xlsx1.  0.35 -1.0  0.047955  0.069054  0.084044
# 4   Inner (A-1)  104.xlsx1.  0.96 -0.2  0.048518  0.069309  0.084575
# ..                      ...   ...  ...       ...       ...       ...
# 79   Inner (A-1)  94.xlsx1.  0.29 -0.2  0.048880  0.065408  0.081628
# 80   Inner (A-1)  95.xlsx1.  0.26 -0.9  0.046928  0.070716  0.084841
# 81   Inner (A-1)  96.xlsx1.  0.26 -0.3  0.046246  0.064349  0.079217
# 82   Inner (A-1)  97.xlsx1.  0.33 -0.9  0.046976  0.068309  0.082874
# 83   Inner (A-1)  98.xlsx1.  0.26 -0.2  0.047525  0.062381  0.078397
#
#     Skewness   Kurtosis   P2P  Crest Factor  Variance  Fault Defect
# 0   0.001269   1.847866  0.12      3.994980  0.004133  inner    Yes
# ...

# %%
in2
# Out:
#                 Unnamed: 0   Max   Min      Mean       Std       RMS  \
# 0    Inner (A-2)  1.xlsx1.  0.42 -0.40  0.049869  0.093613  0.106026
# 1   Inner (A-2)  11.xlsx1.  0.93 -0.97  0.053725  0.106987  0.119671
# 2   Inner (A-2)  12.xlsx1.  0.62 -0.40  0.048531  0.094655  0.106329
# 3   Inner (A-2)  13.xlsx1.  0.38 -0.30  0.047250  0.087222  0.099159
# 4   Inner (A-2)  14.xlsx1.  0.88 -0.30  0.049041  0.091184  0.103495
# ..                     ...   ...   ...       ...       ...       ...
# 84   Inner (A-2)  9.xlsx1.  0.39 -0.40  0.049150  0.090887  0.103285
# 85  Inner (A-2)  90.xlsx1.  0.59 -0.90  0.031513  0.125771  0.129597
# 86  Inner (A-2)  92.xlsx1.  0.73 -0.50  0.028194  0.131590  0.134511
# 87  Inner (A-2)  93.xlsx1.  0.68 -0.50  0.031677  0.123770  0.127699
# 88  Inner (A-2)  94.xlsx1.  0.66 -0.50  0.030444  0.133355  0.136721
#
#     Skewness   Kurtosis   P2P  Crest Factor  Variance  Fault Defect
# 0  -0.147743   2.129546  0.02      3.961296  0.008763  inner    Yes
# ...

# %%
in3
# Out:
#                  Unnamed: 0   Max  Min      Mean       Std       RMS  \
# 0     Inner (A-3)  1.xlsx1.  0.90 -1.0 -0.025664  0.116444  0.119181
# 1    Inner (A-3)  10.xlsx1.  0.81 -0.9 -0.025271  0.110987  0.113774
# 2   Inner (A-3)  100.xlsx1.  0.27 -0.8 -0.031998  0.099887  0.104839
# 3   Inner (A-3)  101.xlsx1.  0.96 -0.4 -0.025612  0.099701  0.102889
# 4    Inner (A-3)  11.xlsx1.  0.29 -1.0 -0.022477  0.109053  0.111292
# ..                      ...   ...  ...       ...       ...       ...
# 89   Inner (A-3)  94.xlsx1.  0.26 -8.0 -0.049858  0.327518  0.331127
# 90   Inner (A-3)  95.xlsx1.  0.38 -0.9 -0.026855  0.103655  0.107027
# 91   Inner (A-3)  96.xlsx1.  0.27 -0.4 -0.020945  0.097506  0.099682
# 92   Inner (A-3)  98.xlsx1.  0.75 -1.0 -0.025267  0.111543  0.114314
# 93   Inner (A-3)  99.xlsx1.  0.88 -0.5 -0.030956  0.105145  0.109556
#
#      Skewness    Kurtosis   P2P  Crest Factor  Variance  Fault Defect
# ...

# %%
h1=pd.read_csv(r'C:\Users\User\Desktop\healthydataset\healthyA1.csv')
h2=pd.read_csv(r'C:\Users\User\Desktop\healthydataset\healthyA2.csv')

# %%
h1
# Out:
#                    Unnamed: 0   Max  Min      Mean       Std       RMS  \
# 0     Healthy (A-1)  1.xlsx1.  1.10 -0.2  0.169819  0.076494  0.186236
# 1    Healthy (A-1)  10.xlsx1.  0.47 -0.2  0.169838  0.078767  0.187198
# 2   Healthy (A-1)  100.xlsx1.  0.96 -0.2  0.125431  0.082308  0.150002
# 3   Healthy (A-1)  101.xlsx1.  0.90 -0.1  0.128206  0.084259  0.153392
# 4   Healthy (A-1)  102.xlsx1.  0.91 -0.2  0.129736  0.084179  0.154630
# ..                        ...   ...  ...       ...       ...       ...
# 95   Healthy (A-1)  94.xlsx1.  0.41 -0.1  0.127984  0.080031  0.150925
# 96   Healthy (A-1)  95.xlsx1.  0.47 -0.9  0.125815  0.085945  0.152343
# 97   Healthy (A-1)  96.xlsx1.  0.94 -0.9  0.127416  0.091647  0.156925
# 98   Healthy (A-1)  97.xlsx1.  0.45 -0.1  0.129535  0.081416  0.152975
# 99   Healthy (A-1)  99.xlsx1.  0.94 -0.2  0.129658  0.091785  0.158830
#
#     Skewness   Kurtosis   P2P  Crest Factor  Variance    Fault Defect
# ...

# %%
h2
# Out:
#                     Unnamed: 0   Max  Min      Mean       Std       RMS  \
# 0      Healthy (A-2)  1.xlsx1.  0.29 -0.2  0.129423  0.050388  0.138877
# 1     Healthy (A-2)  10.xlsx1.  0.30 -0.3  0.136279  0.056198  0.147401
# 2    Healthy (A-2)  100.xlsx1.  0.35  0.0  0.135951  0.059025  0.148200
# 3    Healthy (A-2)  101.xlsx1.  0.88  0.0  0.138636  0.065495  0.153315
# 4    Healthy (A-2)  102.xlsx1.  0.35  0.0  0.140161  0.060214  0.152536
# ..                         ...   ...  ...       ...       ...       ...
# 102   Healthy (A-2)  95.xlsx1.  0.94 -0.1  0.138558  0.065252  0.153140
# 103   Healthy (A-2)  96.xlsx1.  0.36  0.0  0.142690  0.059884  0.154735
# 104   Healthy (A-2)  97.xlsx1.  0.80  0.0  0.142292  0.061786  0.155115
# 105   Healthy (A-2)  98.xlsx1.  0.94 -0.1  0.142172  0.065569  0.156550
# 106   Healthy (A-2)  99.xlsx1.  0.33  0.0  0.139546  0.058838  0.151431
#
#      Skewness   Kurtosis   P2P  Crest Factor  Variance    Fault Defect
# ...

# %%
o1=pd.read_csv(r'C:\Users\User\Desktop\outerdataset\outerA1.csv')
o2=pd.read_csv(r'C:\Users\User\Desktop\outerdataset\outerA2.csv')
o3=pd.read_csv(r'C:\Users\User\Desktop\outerdataset\outerA3.csv')

# %%
o1
# Out:
#                Unnamed: 0   Max  Min      Mean       Std       RMS  Skewness  \
# 0     Outer RACE 1.xlsx1.  1.16 -0.1  0.158819  0.072427  0.174539  3.272104
# 1   Outer RACE 100.xlsx1.  1.10 -0.2  0.164736  0.087200  0.186371  1.242153
# 2   Outer RACE 101.xlsx1.  0.53 -0.1  0.169099  0.081714  0.187789  0.291947
# 3   Outer RACE 102.xlsx1.  1.19 -0.1  0.168136  0.086328  0.188983  1.661226
# 4   Outer RACE 103.xlsx1.  1.10 -0.1  0.169889  0.084094  0.189544  1.552888
# ..                    ...   ...  ...       ...       ...       ...       ...
# 83   Outer RACE 95.xlsx1.  0.53 -0.1  0.168222  0.081668  0.186980  0.317152
# 84   Outer RACE 96.xlsx1.  0.45 -0.2  0.168707  0.083680  0.188301  0.189785
# 85   Outer RACE 97.xlsx1.  0.54 -0.2  0.165278  0.081366  0.184203  0.032004
# 86   Outer RACE 98.xlsx1.  0.44 -0.2  0.174874  0.081487  0.192910 -0.080564
# 87   Outer RACE 99.xlsx1.  1.10 -0.3  0.166133  0.086813  0.187427  1.279324
#
# ...

# %%
o2
# Out:
#                        Unnamed: 0   Max  Min      Mean       Std       RMS  \
# 0      Outer RACE (A-2)  1.xlsx1.  0.56 -0.1  0.174167  0.083515  0.193136
# 1     Outer RACE (A-2)  10.xlsx1.  0.62  0.0  0.171988  0.082046  0.190537
# 2    Outer RACE (A-2)  100.xlsx1.  1.33 -0.7  0.164525  0.102309  0.193714
# 3    Outer RACE (A-2)  101.xlsx1.  0.56 -0.2  0.166964  0.088094  0.188759
# 4    Outer RACE (A-2)  102.xlsx1.  0.53 -0.1  0.164696  0.090690  0.187992
# ..                            ...   ...  ...       ...       ...       ...
# 106   Outer RACE (A-2)  94.xlsx1.  1.10 -0.1  0.161970  0.089917  0.185232
# 107   Outer RACE (A-2)  95.xlsx1.  1.08 -0.1  0.161871  0.092283  0.186305
# 108   Outer RACE (A-2)  96.xlsx1.  0.56 -0.1  0.161100  0.089870  0.184450
# 109   Outer RACE (A-2)  98.xlsx1.  0.54 -0.1  0.158162  0.085513  0.179778
# 110   Outer RACE (A-2)  99.xlsx1.  1.22 -0.1  0.162218  0.096844  0.188902
#
#      Skewness   Kurtosis   P2P  Crest Factor  Variance  Fault Defect
# ...

# %%
o3
# Out:
#                        Unnamed: 0   Max  Min      Mean       Std       RMS  \
# 0      Outer RACE (A-3)  1.xlsx1.  0.51  0.0  0.168821  0.074227  0.184403
# 1     Outer RACE (A-3)  10.xlsx1.  1.16 -0.2  0.164070  0.085077  0.184797
# 2    Outer RACE (A-3)  100.xlsx1.  0.53 -0.1  0.157381  0.082833  0.177829
# 3    Outer RACE (A-3)  101.xlsx1.  0.54 -0.1  0.160010  0.082705  0.180101
# 4    Outer RACE (A-3)  102.xlsx1.  0.45 -0.1  0.154561  0.081470  0.174699
# ..                            ...   ...  ...       ...       ...       ...
# 102   Outer RACE (A-3)  95.xlsx1.  0.48 -0.2  0.154127  0.082089  0.174605
# 103   Outer RACE (A-3)  96.xlsx1.  0.48 -0.1  0.152729  0.084977  0.174757
# 104   Outer RACE (A-3)  97.xlsx1.  0.44 -0.1  0.155634  0.078743  0.174402
# 105   Outer RACE (A-3)  98.xlsx1.  1.23 -0.2  0.156200  0.088078  0.179299
# 106   Outer RACE (A-3)  99.xlsx1.  0.48 -0.3  0.153169  0.087728  0.176491
#
#      Skewness   Kurtosis   P2P  Crest Factor  Variance  Fault Defect
# ...

# %%
r1=pd.read_csv(r'C:\Users\User\Desktop\rollerdataset\rollerA1.csv')
r2=pd.read_csv(r'C:\Users\User\Desktop\rollerdataset\rollerA2.csv')
r3=pd.read_csv(r'C:\Users\User\Desktop\rollerdataset\rollerA3.csv')

# %%
r1
# Out:
#                Unnamed: 0   Max   Min      Mean       Std       RMS  Skewness  \
# 0   ROLLER FAULT10.xlsx1.  0.54  0.00  0.288074  0.066940  0.295742 -0.595890
# 1   ROLLER FAULT11.xlsx1.  0.55  0.00  0.290169  0.066936  0.297782 -0.418678
# 2   ROLLER FAULT12.xlsx1.  0.49  0.00  0.284463  0.065959  0.291999 -0.768844
# 3   ROLLER FAULT13.xlsx1.  0.51  0.00  0.288599  0.066192  0.296085 -0.524733
# 4   ROLLER FAULT14.xlsx1.  0.55  0.00  0.287538  0.063887  0.294542 -0.276429
# 5   ROLLER FAULT15.xlsx1.  0.54 -0.10  0.288591  0.069566  0.296849 -0.630751
# 6   ROLLER FAULT16.xlsx1.  0.57  0.02  0.282741  0.065049  0.290120 -0.142237
# 7   ROLLER FAULT17.xlsx1.  0.57  0.00  0.282641  0.065599  0.290146 -0.255553
# 8   ROLLER FAULT18.xlsx1.  0.49  0.01  0.285885  0.071992  0.294799 -0.605202
# 9   ROLLER FAULT19.xlsx1.  0.41  0.00  0.223990  0.061879  0.232372 -0.519669
# 10  ROLLER FAULT20.xlsx1.  0.42 -0.10  0.213974  0.066106  0.223943 -0.575096
# ...

# %%
r2
# Out:
#                Unnamed: 0   Max   Min      Mean       Std       RMS  Skewness  \
# 0   ROLLER FAULT25.xlsx1.  0.36 -0.19  0.156204  0.041061  0.161506 -0.807182
# 1   ROLLER FAULT26.xlsx1.  0.51 -0.20  0.153582  0.078895  0.172643  0.232209
# 2   ROLLER FAULT27.xlsx1.  1.13 -0.10  0.150838  0.084108  0.172682  1.612978
# 3   ROLLER FAULT28.xlsx1.  1.00 -0.10  0.149424  0.085048  0.171911  1.442888
# 4   ROLLER FAULT30.xlsx1.  1.02 -0.10  0.146847  0.079799  0.167110  1.504353
# ..                    ...   ...   ...       ...       ...       ...       ...
# 56  ROLLER FAULT85.xlsx1.  0.65 -0.20  0.137798  0.101228  0.170953  0.565342
# 57  ROLLER FAULT86.xlsx1.  1.20 -0.40  0.142249  0.112648  0.181416  1.490079
# 58  ROLLER FAULT87.xlsx1.  0.63 -0.20  0.137271  0.105348  0.173004  0.849797
# 59  ROLLER FAULT88.xlsx1.  0.73 -0.20  0.141852  0.104046  0.175888  0.572960
# 60  ROLLER FAULT90.xlsx1.  0.68 -0.50  0.140363  0.106718  0.176292  0.274460
#
# ...

# %%
r3
# Out:
#                 Unnamed: 0   Max  Min      Mean       Std       RMS  Skewness  \
# 0     ROLLER FAULT1.xlsx1.  0.53 -0.2  0.164034  0.094339  0.189204  0.422914
# 1    ROLLER FAULT10.xlsx1.  0.54 -0.1  0.166179  0.084336  0.186336  0.374001
# 2   ROLLER FAULT100.xlsx1.  0.53 -0.5  0.159366  0.085779  0.180965  0.031541
# 3   ROLLER FAULT101.xlsx1.  1.14 -0.2  0.159939  0.085265  0.181227  1.623736
# 4   ROLLER FAULT102.xlsx1.  1.00 -0.2  0.157545  0.082946  0.178027  1.081907
# ..                     ...   ...  ...       ...       ...       ...       ...
# 93   ROLLER FAULT95.xlsx1.  0.51 -0.2  0.155025  0.080029  0.174445  0.055514
# 94   ROLLER FAULT96.xlsx1.  0.54 -0.2  0.160798  0.081969  0.180467  0.347105
# 95   ROLLER FAULT97.xlsx1.  0.53 -0.2  0.157371  0.078050  0.175645  0.360563
# 96   ROLLER FAULT98.xlsx1.  1.04 -0.2  0.160827  0.086393  0.182542  1.437458
# 97   ROLLER FAULT99.xlsx1.  0.48 -0.1  0.155856  0.079520  0.174952  0.399247
#
# ...

# %%
df_concat =pd.concat([in1,in2,in3,o1,o2,o3,h1,h2,r1,r2,r3])
df = df.reset_index(drop=True)
df_concat=df_concat.drop(columns=['Unnamed: 0'])
df_concat.dropna()
# Out:
#      Max  Min      Mean       Std       RMS  Skewness   Kurtosis   P2P  \
# 0   0.32 -0.2  0.047824  0.064290  0.080101  0.001269   1.847866  0.12
# 1   0.96 -0.2  0.049203  0.074959  0.089633  3.380106  38.374250  0.76
# 2   0.90 -0.2  0.047670  0.067443  0.082561  2.494656  26.407668  0.70
# 3   0.35 -1.0  0.047955  0.069054  0.084044 -3.219543  53.590734 -0.65
# 4   0.96 -0.2  0.048518  0.069309  0.084575  2.487599  30.184741  0.76
# ..   ...  ...       ...       ...       ...       ...        ...   ...
# 93  0.51 -0.2  0.155025  0.080029  0.174445  0.055514   1.682962  0.31
# 94  0.54 -0.2  0.160798  0.081969  0.180467  0.347105   1.352100  0.34
# 95  0.53 -0.2  0.157371  0.078050  0.175645  0.360563   2.130960  0.33
# 96  1.04 -0.2  0.160827  0.086393  0.182542  1.437458  11.497220  0.84
# 97  0.48 -0.1  0.155856  0.079520  0.174952  0.399247   1.456687  0.38
#
#     Crest Factor  Variance   Fault Defect
# 0       3.994980  0.004133   inner    Yes
# ...

# %%
path=r'C:\Users\User\Desktop\ '
df_concat.to_csv(path+'original_dataset.csv')
